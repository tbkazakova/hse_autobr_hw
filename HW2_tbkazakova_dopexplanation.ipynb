# %% [markdown]
# В задании обещают ещё балл за объяснение, почему были взяты 3 определённых вида синтаксических групп.
#
# Я выбрала прилагательное+существительное, (наречие+глагол|глагол+наречие) (брала бы как одну группу), не+глагол. Дальше объяснение.
#
# У меня тексты про машины. "Барахлит", "ломается" и т.д. может встречаться и в отрицательных отзывах, и в положительных (потому что хорошие машины не барахлят, не ломаются и об этом люди пишут). Получается "не+барахлит" - замечательная характеристика
# Похожая ситуация с наречиями и прилагательными. В зависимости от того, к чему они относятся, они могут быть положительными и отрицательными. Ср. быстро расходуется (топливо) и быстро разгоняется. Ср. быстрый расход (топлива) и быстрый разгон.

# %%
# Опоздала меньше, чем на два дня. По идее за это +0,8 балла.
